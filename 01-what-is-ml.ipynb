# %% [markdown]
# <a href="https://colab.research.google.com/github/BIGGG-BOT/ML-/blob/main/01-what-is-ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# What is Machine Learning?

&gt; Arthur Samuel (1959):
&gt; "Machine Learning is the field of study that gives computers the ability to learn without being explicitly programmed."

&gt; Tom Mitchell (1998):
&gt; "A computer program is said to learn from experience E with respect to some task T and some performance measure P, if its performance on T, as measured by P, improves with experience E."

---

## 我自己的理解
机器从数据里自己找规律，不需要人一条一条的写规则和修改。人只需要给data。
# Out:
#   File "/tmp/ipykernel_1736/3930777980.py", line 12
#     机器从数据里自己找规律，不需要人一条一条的写规则和修改。人只需要给data。
#                ^
# SyntaxError: invalid character '，' (U+FF0C)
